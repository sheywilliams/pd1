# %%
# pandas assignment
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Assignment 1

# %%
# import car price dataset
data = pd.read_csv('C:\\Users\\shaw liam\\Documents\\Datasets\\carprice.csv')
data.head()
# Out:
# C:\Users\shaw liam\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         dateCrawled                            name  seller offerType  \
# 0  24/03/2016 11:52                      Golf_3_1.6  privat   Angebot
# 1  24/03/2016 10:58            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  14/03/2016 12:52  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  17/03/2016 16:54              GOLF_4_1_4__3T�RER  privat   Angebot
# 4  31/03/2016 17:25  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#      price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480.0   test         NaN              1993.0    manuell      0.0   golf
# 1  18300.0   test       coupe              2011.0    manuell    190.0    NaN
# ...

# %%
#extract all the values that is not null from the dataset to a new variable 
# data[data.notnull()].head()
exp = data[data.notnull().head()]
exp
# Out:
#              dateCrawled                            name  seller offerType  \
# 0       24/03/2016 11:52                      Golf_3_1.6  privat   Angebot
# 1       24/03/2016 10:58            A5_Sportback_2.7_Tdi  privat   Angebot
# 2       14/03/2016 12:52  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3       17/03/2016 16:54              GOLF_4_1_4__3T�RER  privat   Angebot
# 4       31/03/2016 17:25  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# ...                  ...                             ...     ...       ...
# 371534               NaN                             NaN     NaN       NaN
# 371535               NaN                             NaN     NaN       NaN
# 371536               NaN                             NaN     NaN       NaN
# 371537               NaN                             NaN     NaN       NaN
# 371538               NaN                             NaN     NaN       NaN
#
# ...

# %%
# extract all the null values into a new varaible
edu = data[data.isnull().head()]
edu
# Out:
#        dateCrawled name seller offerType  price abtest vehicleType  \
# 0              NaN  NaN    NaN       NaN    NaN    NaN         NaN
# 1              NaN  NaN    NaN       NaN    NaN    NaN         NaN
# 2              NaN  NaN    NaN       NaN    NaN    NaN         NaN
# 3              NaN  NaN    NaN       NaN    NaN    NaN         NaN
# 4              NaN  NaN    NaN       NaN    NaN    NaN         NaN
# ...            ...  ...    ...       ...    ...    ...         ...
# 371534         NaN  NaN    NaN       NaN    NaN    NaN         NaN
# 371535         NaN  NaN    NaN       NaN    NaN    NaN         NaN
# 371536         NaN  NaN    NaN       NaN    NaN    NaN         NaN
# 371537         NaN  NaN    NaN       NaN    NaN    NaN         NaN
# 371538         NaN  NaN    NaN       NaN    NaN    NaN         NaN
#
#         yearOfRegistration gearbox  powerPS model kilometer  \
# 0                      NaN     NaN      NaN   NaN       NaN
# ...

# %%
# drop all columns containing null values from the original dataset 
data.dropna()
# Out:
#              dateCrawled                                               name  \
# 3       17/03/2016 16:54                                 GOLF_4_1_4__3T�RER
# 4       31/03/2016 17:25                     Skoda_Fabia_1.4_TDI_PD_Classic
# 5       04/04/2016 17:36  BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...
# 6       01/04/2016 20:48                        Peugeot_206_CC_110_Platinum
# 7       21/03/2016 18:54                       VW_Derby_Bj_80__Scheunenfund
# ...                  ...                                                ...
# 371531  19/03/2016 19:53                                       turbo_defekt
# 371532  27/03/2016 20:36                 Opel_Zafira_1.6_Elegance_T�V_12/16
# 371535  05/03/2016 19:56              Smart_smart_leistungssteigerung_100ps
# 371536  19/03/2016 18:57                 Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371538  07/03/2016 19:39       BMW_M135i_vollausgestattet_NP_52.720____Euro
#
# ...

# %%
# compute the sum, mean of the price column on the dataset 
np.nansum(data.price)
# Out:
# 6425912999.0

# %%
np.nanmean(data.price)
# Out:
# 17295.439494748854

# %%
# get the car with the lowest price and with the highest price
data.name[data.price.argmin()]
# Out:
# 'VW_Derby_Bj_80__Scheunenfund'

# %%
data.name[data.price.argmax()]
# Out:
# 'Kaufe_AUTOS_Zum_basteln'

# %%
# Assignment 2
# highest score under english in ss1
# highest score under maths in ss2
# highest score under s/s in ss3
# highest total score in agric(ss1-ss3/)

# %%
school_data = pd.read_csv("C:\\Users\\User\\Documents\\Data science\\Datasets\\student record.csv")
school_data
# Out:
#             Name  SS1  SS2  SS3  SS1.1  SS2.1  SS3.1  SS1.2  SS2.2  SS3.2  \
# 0        Ade Ojo   80   95   58     96     95     95     74     69     75
# 1  Sunday Joshua   58   62   96     58     48     58     75     85     59
# 2   Charse Akpan   75   86   75     68     65     65     98     75     87
# 3    Samuel Tran   68   49   45     95     57     58     78     94     98
# 4   Success Edom   56   75   75     75     75     46     58     45     65
# 5  Adeola thomas   74   63   58     45     85     75     45     78     45
# 6   Aluko Sandra   85   52   98     65     98     58     78     65     95
# 7   Ochuwko Chuk   98   81   57     95     47     98     54     85     87
# 8  Ibraheem Lola   95   45   85     75     85     75     85     75     54
# 9   Sordiq Abdul   84   58   68     74     85     94     81     74     54
#
#    SS1.3  SS2.3  SS3.3
# 0     85     74     96
# 1     65     75     58
# 2     63     98     68
# 3     95     78     95
# 4     41     58     75
# ...

# %%
columns = pd.MultiIndex.from_product([['English','Maths', 'Social Study', 'Agriculture'], 
                                      ['SS1','SS2','SS3']], names=['subject', 'Class'])
school_data = school_data.set_index("Name")
school_data.columns=columns
school_data
# Out:
# subject       English         Maths         Social Study         Agriculture  \
# Class             SS1 SS2 SS3   SS1 SS2 SS3          SS1 SS2 SS3         SS1
# Name
# Ade Ojo            80  95  58    96  95  95           74  69  75          85
# Sunday Joshua      58  62  96    58  48  58           75  85  59          65
# Charse Akpan       75  86  75    68  65  65           98  75  87          63
# Samuel Tran        68  49  45    95  57  58           78  94  98          95
# Success Edom       56  75  75    75  75  46           58  45  65          41
# Adeola thomas      74  63  58    45  85  75           45  78  45          42
# Aluko Sandra       85  52  98    65  98  58           78  65  95          58
# Ochuwko Chuk       98  81  57    95  47  98           54  85  87          67
# Ibraheem Lola      95  45  85    75  85  75           85  75  54          52
# Sordiq Abdul       84  58  68    74  85  94           81  74  54          47
#
# subject
# Class         SS2 SS3
# ...

# %%
sn = np.arange(1,11)
index = pd.MultiIndex.from_arrays([sn, student_name], names=['S/N', 'Student Name'])
student_name
# Out:
# Index(['Ade Ojo', 'Sunday Joshua', 'Charse Akpan', 'Samuel Tran',
#        'Success Edom', 'Adeola thomas', 'Aluko Sandra', 'Ochuwko Chuk',
#        'Ibraheem Lola', 'Sordiq Abdul'],
#       dtype='object', name='Name')

# %%
student_name = school_data.index
student_name
# Out:
# Index(['Ade Ojo', 'Sunday Joshua', 'Charse Akpan', 'Samuel Tran',
#        'Success Edom', 'Adeola thomas', 'Aluko Sandra', 'Ochuwko Chuk',
#        'Ibraheem Lola', 'Sordiq Abdul'],
#       dtype='object', name='Name')

# %%
student_name = school_data.index
student_score =school_data.values
report_card = pd.DataFrame(student_score, index=index, columns=columns)
report_card
# Out:
# subject           English         Maths         Social Study          \
# Class                 SS1 SS2 SS3   SS1 SS2 SS3          SS1 SS2 SS3
# S/N Student Name
# 1   Ade Ojo            80  95  58    96  95  95           74  69  75
# 2   Sunday Joshua      58  62  96    58  48  58           75  85  59
# 3   Charse Akpan       75  86  75    68  65  65           98  75  87
# 4   Samuel Tran        68  49  45    95  57  58           78  94  98
# 5   Success Edom       56  75  75    75  75  46           58  45  65
# 6   Adeola thomas      74  63  58    45  85  75           45  78  45
# 7   Aluko Sandra       85  52  98    65  98  58           78  65  95
# 8   Ochuwko Chuk       98  81  57    95  47  98           54  85  87
# 9   Ibraheem Lola      95  45  85    75  85  75           85  75  54
# 10  Sordiq Abdul       84  58  68    74  85  94           81  74  54
#
# subject           Agriculture
# Class                     SS1 SS2 SS3
# S/N Student Name
# ...

# %%
# highest score under english in ss1
english = report_card['English', 'SS1']
maxi = english.max()
english[english >= maxi]
# Out:
# S/N  Student Name
# 8    Ochuwko Chuk    98
# Name: (English, SS1), dtype: int64

# %%
# highest score under maths in ss2
maths = report_card['Maths', 'SS2']
ss = maths.max()
ss
# ss[ss >= maths]
# Out:
# 98

# %%
# highest score under s/s in ss3
sos = report_card['Social Study', 'SS3']
s_s = sos.max()
s_s
# s_s [s_s >= sos]
# Out:
# 98

# %%
# highest total score in agric(ss1-ss3/)
total = report_card.sum(axis = 1, level= "subject")
total
# Out:
# subject            English  Maths  Social Study  Agriculture
# S/N Student Name
# 1   Ade Ojo            233    286           218          255
# 2   Sunday Joshua      216    164           219          198
# 3   Charse Akpan       236    198           260          229
# 4   Samuel Tran        162    210           270          268
# 5   Success Edom       206    196           168          174
# 6   Adeola thomas      195    205           168          132
# 7   Aluko Sandra       235    221           238          201
# 8   Ochuwko Chuk       236    240           226          216
# 9   Ibraheem Lola      225    235           214          212
# 10  Sordiq Abdul       210    253           209          202

# %%
agr = total.Agriculture
agric = agr.max()
agric
# agric [agric >= agr]
# Out:
# 268

# %%
# Assignment 3
# using sales data 1. month and price each(sort by highest to lowest price) 2. product with 
# the highest
# price(which comprises the quantity ordered and month) 
# 3. top 5 and bottom 5 in december(day and price each)

# %%
dec = pd.read_csv("C:\\Users\\User\\Documents\\Data science\\Sales_Data\\Sales_December_2019.csv")
nov = pd.read_csv("C:\\Users\\User\\Documents\\Data science\\Sales_Data\\Sales_November_2019.csv")
# octo = pd.read_csv("C:\\Users\\User\\Documents\\Data science\\Sales_Data\\Sales_October_2019.csv")
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       278797            Wired Headphones                1      11.99
# 1       278798        USB-C Charging Cable                2      11.95
# 2       278799    Apple Airpods Headphones                1      150.0
# 3       278800            27in FHD Monitor                1     149.99
# 4       278801  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 17656   295660      AAA Batteries (4-pack)                2       2.99
# 17657   295661        USB-C Charging Cable                1      11.95
# 17658   295662    Lightning Charging Cable                1      14.95
# 17659   295663      AAA Batteries (4-pack)                1       2.99
# 17660   295664                Google Phone                1        600
#
#            Order Date                      Purchase Address
# ...

# %%
lx = nov.merge(dec)
lx
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 0          NaN      NaN               NaN         NaN         NaN
# 1          NaN      NaN               NaN         NaN         NaN
# 2          NaN      NaN               NaN         NaN         NaN
# 3          NaN      NaN               NaN         NaN         NaN
# 4          NaN      NaN               NaN         NaN         NaN
# ...        ...      ...               ...         ...         ...
# 5323  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 5324  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 5325  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 5326  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 5327  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#       Purchase Address
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# ...

# %%
# 1.date and price, sort from highest to lowest
# dec.columns = dec.columns.str.replace(' ', '')
# print('\n\n', dec)
nov.columns = nov.columns.str.replace(' ', '')

# %%
# Assignment 4
#import Califonial_cities dataset and perform the following activities on it:
#1. make cities column an index #2. describe the dataset #3. extract the city with highest population 
#4. calculate the sum of the dataset along column axis

# %%
cali = pd.read_csv("C:\\Users\\User\\Documents\\Data science\\Datasets\\california_cities.csv")
cali
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 2             2      Alameda  37.756111 -122.274444          NaN
# 3             3       Albany  37.886944 -122.297778          NaN
# 4             4     Alhambra  34.081944 -118.135000        150.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# ...

# %%
# 1. make cities column an index
cal = cali.set_index(cali.city)
cal
# Out:
#              Unnamed: 0         city       latd       longd  elevation_m  \
# city
# Adelanto              0     Adelanto  34.576111 -117.432778        875.0
# AgouraHills           1  AgouraHills  34.153333 -118.761667        281.0
# Alameda               2      Alameda  37.756111 -122.274444          NaN
# Albany                3       Albany  37.886944 -122.297778          NaN
# Alhambra              4     Alhambra  34.081944 -118.135000        150.0
# ...                 ...          ...        ...         ...          ...
# Yountville          477   Yountville  38.403056 -122.362222         30.0
# Yreka               478        Yreka  41.726667 -122.637500        787.0
# YubaCity            479     YubaCity  39.134722 -121.626111         18.0
# Yucaipa             480      Yucaipa  34.030278 -117.048611        798.0
# YuccaValley         481  YuccaValley  34.133333 -116.416667       1027.0
#
#              elevation_ft  population_total  area_total_sq_mi  \
# city
# ...

# %%
# 2. describe the dataset
cal.describe
# Out:
# <bound method NDFrame.describe of              Unnamed: 0         city       latd       longd  elevation_m  \
# city
# Adelanto              0     Adelanto  34.576111 -117.432778        875.0
# AgouraHills           1  AgouraHills  34.153333 -118.761667        281.0
# Alameda               2      Alameda  37.756111 -122.274444          NaN
# Albany                3       Albany  37.886944 -122.297778          NaN
# Alhambra              4     Alhambra  34.081944 -118.135000        150.0
# ...                 ...          ...        ...         ...          ...
# Yountville          477   Yountville  38.403056 -122.362222         30.0
# Yreka               478        Yreka  41.726667 -122.637500        787.0
# YubaCity            479     YubaCity  39.134722 -121.626111         18.0
# Yucaipa             480      Yucaipa  34.030278 -117.048611        798.0
# YuccaValley         481  YuccaValley  34.133333 -116.416667       1027.0
#
# ...

# %%
# 3. extract the city with the highest population
# cali.population_total.max()

# %%
# cal.groupby('latd')['population_total'].max()

# %%
cali_pop = cal['population_total']
pop_max = cali_pop.max()
cali_pop[cali_pop >= pop_max]
# Out:
# city
# LosAngeles    3884307
# Name: population_total, dtype: int64

# %%
cal.sort_values(by ='population_total', ascending = False)
# Out:
#               Unnamed: 0          city       latd       longd  elevation_m  \
# city
# LosAngeles           239    LosAngeles  34.050000 -118.250000         71.0
# SanDiego             367      SanDiego  32.715000 -117.162500          6.0
# SanJose              375       SanJose  37.333333 -121.900000         26.0
# SanFrancisco         370  SanFrancisco  37.783333 -122.416667          NaN
# Fresno               150        Fresno  36.750000 -119.766667          NaN
# ...                  ...           ...        ...         ...          ...
# SandCity             366      SandCity  36.617222 -121.848333         22.0
# Industry             190      Industry  34.016667 -117.950000         98.0
# AmadorCity             7    AmadorCity  38.419444 -120.824167        280.0
# Vernon               448        Vernon  34.001111 -118.211111         62.0
# Pomona               327        Pomona  34.060833 -117.755833        259.0
#
# ...

# %%
# 4. calculate the sum of the data set along columns
cali.sum(axis = 'columns')
# Out:
# 0      35830.442333
# 1      21505.925667
# 2      75636.121667
# 3      19037.110167
# 4      83705.752944
#            ...
# 477     3465.034833
# 478    11603.986167
# 479    65504.268611
# 480    55380.275667
# 481    25782.024667
# Length: 482, dtype: float64

# %%
# Assignment 5
# 1. clean and analyze the dataset with pandas and groupby and pivot table

# %%
sample = pd.read_csv("C:\\Users\\User\\Documents\\Data science\\Datasets\\titanic\\gender_submission.csv")
sample
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
fx = pd.merge(sample, test, train)
sample.concat(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-3905038af3c8> in <module>
# ----> 1 fx = pd.merge(sample, test, train)
#       2 sample.concat(test)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     666             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     667
# --> 668         join_index, left_indexer, right_indexer = self._get_join_info()
#     669
#     670         llabels, rlabels = _items_overlap_with_suffix(
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
# ...

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.7 KB

# %%
# describe the dataset
sample.describe()
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.363636
# std     120.810458    0.481622
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %%
test = pd.read_csv("C:\\Users\\User\\Documents\\Data science\\Datasets\\titanic\\test.csv")
test.head(5)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# describe the dataset
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
test.dropna()
# Out:
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 28           920       1                            Brady, Mr. John Bertram
# ..           ...     ...                                                ...
# 404         1296       1                       Frauenthal, Mr. Isaac Gerald
# 405         1297       2       Nourney, Mr. Alfred (Baron von Drachstedt")"
# 407         1299       1                         Widener, Mr. George Dunton
# 411         1303       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
#
# ...

# %%
# test.drop(axis = 1, columns = ['Cabin'])

# %%
# 1. Id against LotFrontage and LotArea
# test.groupby('Id')[['LotFrontage', 'LotArea']].sum()
# 2. Year with most sales
# test.MoSold.argmax()
# test.YrSold[313]

# %%
train = pd.read_csv("C:\\Users\\User\\Documents\\Data science\\Datasets\\titanic\\train.csv")
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tr.pivot_table('SalePrice', index='Id', columns='YrSold', aggfunc='mean').plot()
# Out:
# <AxesSubplot:xlabel='Id'>

# %%
tr.pivot_table('MSSubClass', index='Id', columns='MSZoning', aggfunc='mean').plot()
# Out:
# <AxesSubplot:xlabel='Id'>

# %%
# PROJECT
# import from webpage then analyze data with pd

# %%
# from bs4 import BeautifulSoup as soup
# from urllib.request import urlopen as uReq
# my_url = ('https://www.flipkart.com/beauty-and-grooming/hair-care-and-accessory/pr?sid=g9b,lcf&p[]=facets.serviceability%5B%5D%3Dtrue&otracker=categorytree&otracker=nmenu_sub_Women_0_Hair%20Care')
# uClient = uReq(my_url)
# page_html = uClient.read()
# uClient.close()

# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq
my_url="https://www.flipkart.com/search?q=samsung+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_HistoryAutoSuggest_0_2&otracker1=AS_QueryStore_HistoryAutoSuggest_0_2&as-pos=0&as-type=HISTORY&as-searchtext=sa"
uClient = uReq(my_url)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...

# %%
tv = pd.read_csv('C:\\Users\\User\\Documents\\Data science\\Datasets\\tv_shows.csv')
tv.head(15)
# Out:
#     Unnamed: 0                       Title  Year  Age  IMDb Rotten Tomatoes  \
# 0            0                Breaking Bad  2008  18+   9.5             96%
# 1            1             Stranger Things  2016  16+   8.8             93%
# 2            2                 Money Heist  2017  18+   8.4             91%
# 3            3                    Sherlock  2010  16+   9.1             78%
# 4            4            Better Call Saul  2015  18+   8.7             97%
# 5            5                  The Office  2005  16+   8.9             81%
# 6            6                Black Mirror  2011  18+   8.8             83%
# 7            7                Supernatural  2005  16+   8.4             93%
# 8            8              Peaky Blinders  2013  18+   8.8             92%
# 9            9  Avatar: The Last Airbender  2005   7+   9.2            100%
# 10          10            The Walking Dead  2010  18+   8.2             81%
# ...

# %%
tv.dropna()
# Out:
#       Unnamed: 0                        Title  Year  Age  IMDb  \
# 0              0                 Breaking Bad  2008  18+   9.5
# 1              1              Stranger Things  2016  16+   8.8
# 2              2                  Money Heist  2017  18+   8.4
# 3              3                     Sherlock  2010  16+   9.1
# 4              4             Better Call Saul  2015  18+   8.7
# ...          ...                          ...   ...  ...   ...
# 5509        5509  Diary of a Future President  2020   7+   5.5
# 5517        5517                      Encore!  2019   7+   7.4
# 5522        5522         Spider-Man Unlimited  1999   7+   6.5
# 5530        5530    The Super Hero Squad Show  2009   7+   6.1
# 5575        5575        Marvel's Hero Project  2019   7+   6.1
#
#      Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  type
# 0                96%        1     0            0        0     1
# 1                93%        1     0            0        0     1
# ...
